# %%
# learning list

# arr = [122,6];
print(arr)
# Out:
# [122, 6]

# %%
name1 = "arhab"
name2 = "adnan";
name3 = "faroq";
name4 = "danish";
name5 = "ayesha";
name6 = "hamna";
print(name1+","+name2+","+name3+","+name4+","+name5+","+name6)
# Out:
# arhab,adnan,faroq,danish,ayesha,hamna
